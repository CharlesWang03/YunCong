# %% [markdown]
# # Data Exploration
# Load processed listings and inspect distributions.

# %%
import pandas as pd
from src.data_pipeline.repository import DataRepository
repo = DataRepository()
df = repo.load()
df.describe(include='all')
